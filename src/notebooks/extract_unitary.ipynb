# %%
from corral_crowding.detuning_fit import compute_infidelity_parameters
import numpy as np

detuning_list = np.linspace(50, 1000, 64)
compute_infidelity_parameters(detuning_list, 0.08, 1.8, 0.12, 60e6)
# Out:
# Quantum object: dims=[[2, 2, 2], [2, 2, 2]], shape=(8, 8), type='oper', dtype=Dense, isherm=False
# Qobj data =
# [[ 1.00000000e+00+0.j          0.00000000e+00+0.j
#    0.00000000e+00+0.j          0.00000000e+00+0.j
#    0.00000000e+00+0.j          0.00000000e+00+0.j
#    0.00000000e+00+0.j          0.00000000e+00+0.j        ]
#  [ 0.00000000e+00+0.j          9.99717509e-01+0.j
#   -1.68069495e-02+0.j          0.00000000e+00+0.j
#    0.00000000e+00-0.01680559j  0.00000000e+00+0.j
#    0.00000000e+00+0.j          0.00000000e+00+0.j        ]
#  [ 0.00000000e+00+0.j         -1.68069495e-02-0.j
#    6.06252372e-05+0.j          0.00000000e+00+0.j
#    0.00000000e+00-0.99985875j  0.00000000e+00+0.j
#    0.00000000e+00+0.j          0.00000000e+00+0.j        ]
#  [ 0.00000000e+00+0.j          0.00000000e+00+0.j
#    0.00000000e+00+0.j         -2.21865441e-04+0.j
#    0.00000000e+00+0.j          0.00000000e+00-0.99985875j
#    0.00000000e+00-0.01680559j  0.00000000e+00+0.j        ]
# ...

# %%
import qutip as qt



kraus_ops = U
