# %%
from corral_crowding.qutrit_module_graph import QutritModuleGraph
from corral_crowding.qutrit_allocation_optimizer import GateFidelityOptimizer

# %%
n = 3
base_freq = [5.0, 5.5, 6.0]
anharmonicities = [-0.29, -0.31, -0.3]
qmg:QutritModuleGraph = QutritModuleGraph(n, edge_type="all-to-all")

# %%
qmg.plot_interaction_frequencies(qutrit_frequencies=base_freq, qutrit_anharmonicities=anharmonicities, snail_frequency=6.7)
qmg.plot_graph(base_freq, snail_frequency=6.7)

# %%
optimizer = GateFidelityOptimizer(
    qmg,
    min_bare_space_ghz=0.12,
    lambdaq=0.08,
    eta=1.8,
    g3=60e6,
    qubit_bounds=(3.3, 5.7),
    snail_bounds=(4.2, 4.7),
    use_lifetime=True,
)

optimizer.optimize_frequencies(256)
optimizer.report_results()
# Out:
# 100%|██████████| 256/256 [00:07<00:00, 32.78it/s]
# Optimization terminated successfully.
# Qubit Frequencies: [5.45995259 5.33993524 5.7       ] GHz
# SNAIL Frequency: 4.200000000000001 GHz
# Gate Infidelities:
#   Gate ('Q0', 'Q1'): 0.120017 GHz → fidelity (no lifetime loss): 9.997892e-01, fidelity (with lifetime loss): 9.984916e-01
#   Gate ('Q0', 'Q2'): 0.240047 GHz → fidelity (no lifetime loss): 9.996627e-01, fidelity (with lifetime loss): 9.983030e-01
#   Gate ('Q1', 'Q2'): 0.360065 GHz → fidelity (no lifetime loss): 9.973433e-01, fidelity (with lifetime loss): 9.959182e-01
#
# Average Gate fidelity (no lifetime loss): 0.999426273474694
# Average Gate fidelity (with lifetime loss): 0.9978138089671383

# %% [markdown]
# # Code for 6 Qutrit topology

# %%
n_6_wrapped_edge_list = [
    ("Q0", "Q1", "qutrit-qutrit", "blue"),
    ("Q0", "Q3", "qutrit-qutrit", "blue"),
    ("Q0", "Q2", "qutrit-qutrit", "blue"),
    ("Q1", "Q3", "qutrit-qutrit", "blue"),
    ("Q1", "Q4", "qutrit-qutrit", "blue"),
    ("Q1", "Q2", "qutrit-qutrit", "blue"),
    ("Q2", "Q4", "qutrit-qutrit", "blue"),
    ("Q2", "Q5", "qutrit-qutrit", "blue"),
    ("Q0", "SNAIL", "snail-qutrit", "orange"),
    ("Q1", "SNAIL", "snail-qutrit", "orange"),
    ("Q2", "SNAIL", "snail-qutrit", "orange"),
    ("Q3", "SNAIL", "snail-qutrit", "orange"),
    ("Q4", "SNAIL", "snail-qutrit", "orange"),
    ("Q5", "SNAIL", "snail-qutrit", "orange"),
]
qmg_6_wrapped = QutritModuleGraph(num_qutrits=6, edge_type="custom", edges=n_6_wrapped_edge_list)

optimizer = GateFidelityOptimizer(
    qmg_6_wrapped,
    min_bare_space_ghz=0.12,
    lambdaq=0.08,
    eta=1.8,
    g3=60e6,
    qubit_bounds=(3.3, 5.7),
    snail_bounds=(4.2, 4.7),
    use_lifetime=True,
)

optimizer.optimize_frequencies(6000)
optimizer.report_results()
# Out:
# 100%|██████████| 6000/6000 [36:45<00:00,  2.72it/s]
# Optimization terminated successfully.
# Qubit Frequencies: [3.31739293 3.43739708 3.91744342 5.66990693 5.44613885 3.67739727] GHz
# SNAIL Frequency: 4.7 GHz
# Gate Infidelities:
#   Gate ('Q0', 'Q1'): 0.120004 GHz → fidelity (no lifetime loss): 9.961702e-01, fidelity (with lifetime loss): 9.949899e-01
#   Gate ('Q0', 'Q3'): 2.352514 GHz → fidelity (no lifetime loss): 9.947310e-01, fidelity (with lifetime loss): 9.894675e-01
#   Gate ('Q0', 'Q2'): 0.600050 GHz → fidelity (no lifetime loss): 9.292196e-01, fidelity (with lifetime loss): 9.278974e-01
#   Gate ('Q1', 'Q3'): 2.232510 GHz → fidelity (no lifetime loss): 9.933161e-01, fidelity (with lifetime loss): 9.888576e-01
#   Gate ('Q1', 'Q4'): 2.008742 GHz → fidelity (no lifetime loss): 9.093189e-01, fidelity (with lifetime loss): 9.061680e-01
#   Gate ('Q1', 'Q2'): 0.480046 GHz → fidelity (no lifetime loss): 9.735094e-01, fidelity (with lifetime loss): 9.721905e-01
# ...

# %%
n_6_no_wrap_edge_list = [
    ("Q0", "Q1", "qutrit-qutrit", "blue"),
    ("Q0", "Q3", "qutrit-qutrit", "blue"),
    ("Q1", "Q3", "qutrit-qutrit", "blue"),
    ("Q1", "Q4", "qutrit-qutrit", "blue"),
    ("Q1", "Q2", "qutrit-qutrit", "blue"),
    ("Q2", "Q4", "qutrit-qutrit", "blue"),
    ("Q2", "Q5", "qutrit-qutrit", "blue"),
    ("Q0", "SNAIL", "snail-qutrit", "orange"),
    ("Q1", "SNAIL", "snail-qutrit", "orange"),
    ("Q2", "SNAIL", "snail-qutrit", "orange"),
    ("Q3", "SNAIL", "snail-qutrit", "orange"),
    ("Q4", "SNAIL", "snail-qutrit", "orange"),
    ("Q5", "SNAIL", "snail-qutrit", "orange"),
]
qmg_6_no_wrap = QutritModuleGraph(num_qutrits=6, edge_type="custom", edges=n_6_no_wrap_edge_list)

optimizer = GateFidelityOptimizer(
    qmg_6_no_wrap,
    min_bare_space_ghz=0.12,
    lambdaq=0.08,
    eta=1.8,
    g3=60e6,
    qubit_bounds=(3.3, 5.7),
    snail_bounds=(4.2, 4.7),
    use_lifetime=True,
)

optimizer.optimize_frequencies(8000)
optimizer.report_results()
# Out:
# 100%|██████████| 8000/8000 [46:22<00:00,  2.87it/s]
# Maximum number of function evaluations has been exceeded.
# Qubit Frequencies: [5.26019199 3.5594556  3.3        5.64137029 5.50191487 5.69533527] GHz
# SNAIL Frequency: 4.200000000003884 GHz
# Gate Infidelities:
#   Gate ('Q0', 'Q1'): 1.700736 GHz → fidelity (no lifetime loss): 8.587619e-01, fidelity (with lifetime loss): 8.559522e-01
#   Gate ('Q0', 'Q3'): 0.381178 GHz → fidelity (no lifetime loss): 9.839676e-01, fidelity (with lifetime loss): 9.825491e-01
#   Gate ('Q1', 'Q3'): 2.081915 GHz → fidelity (no lifetime loss): 9.894202e-01, fidelity (with lifetime loss): 9.843086e-01
#   Gate ('Q1', 'Q4'): 1.942459 GHz → fidelity (no lifetime loss): 9.809076e-01, fidelity (with lifetime loss): 9.767259e-01
#   Gate ('Q1', 'Q2'): 0.259456 GHz → fidelity (no lifetime loss): 9.927140e-01, fidelity (with lifetime loss): 9.913531e-01
# ...

# %% [markdown]
# # Code for 5 Qutrit topology

# %%
n_5_wrapped_edge_list = [
    ("Q0", "Q1", "qutrit-qutrit", "blue"),
    ("Q0", "Q3", "qutrit-qutrit", "blue"),
    ("Q0", "Q2", "qutrit-qutrit", "blue"),
    ("Q1", "Q3", "qutrit-qutrit", "blue"),
    ("Q1", "Q4", "qutrit-qutrit", "blue"),
    ("Q1", "Q2", "qutrit-qutrit", "blue"),
    ("Q2", "Q4", "qutrit-qutrit", "blue"),
    ("Q0", "SNAIL", "snail-qutrit", "orange"),
    ("Q1", "SNAIL", "snail-qutrit", "orange"),
    ("Q2", "SNAIL", "snail-qutrit", "orange"),
    ("Q3", "SNAIL", "snail-qutrit", "orange"),
    ("Q4", "SNAIL", "snail-qutrit", "orange"),
]
qmg_5_wrapped = QutritModuleGraph(num_qutrits=5, edge_type="custom", edges=n_5_wrapped_edge_list)

optimizer = GateFidelityOptimizer(
    qmg_5_wrapped,
    min_bare_space_ghz=0.12,
    lambdaq=0.08,
    eta=1.8,
    g3=60e6,
    qubit_bounds=(3.3, 5.7),
    snail_bounds=(4.2, 4.7),
    use_lifetime=True,
)

optimizer.optimize_frequencies(6000)
optimizer.report_results()
# Out:
# 100%|██████████| 6000/6000 [22:07<00:00,  4.52it/s]
# Optimization terminated successfully.
# Qubit Frequencies: [5.69692724 3.30523351 5.21573381 5.45692724 3.66642661] GHz
# SNAIL Frequency: 4.415718575042369 GHz
# Gate Infidelities:
#   Gate ('Q0', 'Q1'): 2.391694 GHz → fidelity (no lifetime loss): 9.920858e-01, fidelity (with lifetime loss): 9.879914e-01
#   Gate ('Q0', 'Q3'): 0.240000 GHz → fidelity (no lifetime loss): 9.944506e-01, fidelity (with lifetime loss): 9.931539e-01
#   Gate ('Q0', 'Q2'): 0.481193 GHz → fidelity (no lifetime loss): 9.772147e-01, fidelity (with lifetime loss): 9.758106e-01
#   Gate ('Q1', 'Q3'): 2.151694 GHz → fidelity (no lifetime loss): 9.952802e-01, fidelity (with lifetime loss): 9.904195e-01
#   Gate ('Q1', 'Q4'): 0.361193 GHz → fidelity (no lifetime loss): 9.876386e-01, fidelity (with lifetime loss): 9.862880e-01
#   Gate ('Q1', 'Q2'): 1.910500 GHz → fidelity (no lifetime loss): 9.622652e-01, fidelity (with lifetime loss): 9.587747e-01
# ...

# %%
n_5_no_wrap_edge_list = [
    ("Q0", "Q1", "qutrit-qutrit", "blue"),
    ("Q0", "Q3", "qutrit-qutrit", "blue"),
    ("Q1", "Q3", "qutrit-qutrit", "blue"),
    ("Q1", "Q4", "qutrit-qutrit", "blue"),
    ("Q1", "Q2", "qutrit-qutrit", "blue"),
    ("Q2", "Q4", "qutrit-qutrit", "blue"),
    ("Q0", "SNAIL", "snail-qutrit", "orange"),
    ("Q1", "SNAIL", "snail-qutrit", "orange"),
    ("Q2", "SNAIL", "snail-qutrit", "orange"),
    ("Q3", "SNAIL", "snail-qutrit", "orange"),
    ("Q4", "SNAIL", "snail-qutrit", "orange"),
]
qmg_5_no_wrap = QutritModuleGraph(num_qutrits=5, edge_type="custom", edges=n_5_no_wrap_edge_list)

optimizer = GateFidelityOptimizer(
    qmg_5_no_wrap,
    min_bare_space_ghz=0.12,
    lambdaq=0.08,
    eta=1.8,
    g3=60e6,
    qubit_bounds=(3.3, 5.7),
    snail_bounds=(4.2, 4.7),
    use_lifetime=True,
)

optimizer.optimize_frequencies(7500)
optimizer.report_results()
# Out:
# 100%|██████████| 7500/7500 [2:52:41<00:00,  1.38s/it]
# Optimization terminated successfully.
# Qubit Frequencies: [5.45657851 3.30007566 5.21657851 5.69657851 3.66203401] GHz
# SNAIL Frequency: 4.474172128416582 GHz
# Gate Infidelities:
#   Gate ('Q0', 'Q1'): 2.156503 GHz → fidelity (no lifetime loss): 9.953509e-01, fidelity (with lifetime loss): 9.906545e-01
#   Gate ('Q0', 'Q3'): 0.240000 GHz → fidelity (no lifetime loss): 9.930609e-01, fidelity (with lifetime loss): 9.917803e-01
#   Gate ('Q1', 'Q3'): 2.396503 GHz → fidelity (no lifetime loss): 9.918596e-01, fidelity (with lifetime loss): 9.876411e-01
#   Gate ('Q1', 'Q4'): 0.361958 GHz → fidelity (no lifetime loss): 9.887336e-01, fidelity (with lifetime loss): 9.873968e-01
#   Gate ('Q1', 'Q2'): 1.916503 GHz → fidelity (no lifetime loss): 9.672132e-01, fidelity (with lifetime loss): 9.637896e-01
#   Gate ('Q4', 'Q2'): 1.554545 GHz → fidelity (no lifetime loss): 9.599329e-01, fidelity (with lifetime loss): 9.574649e-01
#
# ...

# %% [markdown]
# # Code for 4 Qutrit Topology

# %%
n_4_wrapped_edge_list = [
    ("Q0", "Q1", "qutrit-qutrit", "blue"),
    ("Q0", "Q3", "qutrit-qutrit", "blue"),
    ("Q0", "Q2", "qutrit-qutrit", "blue"),
    ("Q1", "Q3", "qutrit-qutrit", "blue"),
    ("Q1", "Q2", "qutrit-qutrit", "blue"),
    ("Q2", "Q3", "qutrit-qutrit", "blue"),
    ("Q0", "SNAIL", "snail-qutrit", "orange"),
    ("Q1", "SNAIL", "snail-qutrit", "orange"),
    ("Q2", "SNAIL", "snail-qutrit", "orange"),
    ("Q3", "SNAIL", "snail-qutrit", "orange"),
]
qmg_4_wrapped = QutritModuleGraph(num_qutrits=4, edge_type="custom", edges=n_4_wrapped_edge_list)

optimizer = GateFidelityOptimizer(
    qmg_4_wrapped,
    min_bare_space_ghz=0.12,
    lambdaq=0.08,
    eta=1.8,
    g3=60e6,
    qubit_bounds=(3.3, 5.7),
    snail_bounds=(4.2, 4.7),
    use_lifetime=True,
)

optimizer.optimize_frequencies(7500)
optimizer.report_results()
# Out:
# 100%|██████████| 7500/7500 [17:43<00:00,  7.05it/s]
# Optimization terminated successfully.
# Qubit Frequencies: [5.46 3.3  5.1  5.7 ] GHz
# SNAIL Frequency: 4.233885785394494 GHz
# Gate Infidelities:
#   Gate ('Q0', 'Q1'): 2.160000 GHz → fidelity (no lifetime loss): 9.952702e-01, fidelity (with lifetime loss): 9.903163e-01
#   Gate ('Q0', 'Q3'): 0.240000 GHz → fidelity (no lifetime loss): 9.963292e-01, fidelity (with lifetime loss): 9.949831e-01
#   Gate ('Q0', 'Q2'): 0.360000 GHz → fidelity (no lifetime loss): 9.945301e-01, fidelity (with lifetime loss): 9.931192e-01
#   Gate ('Q1', 'Q3'): 2.400000 GHz → fidelity (no lifetime loss): 9.881339e-01, fidelity (with lifetime loss): 9.844940e-01
#   Gate ('Q1', 'Q2'): 1.800000 GHz → fidelity (no lifetime loss): 9.816299e-01, fidelity (with lifetime loss): 9.781421e-01
#   Gate ('Q3', 'Q2'): 0.600000 GHz → fidelity (no lifetime loss): 9.802269e-01, fidelity (with lifetime loss): 9.786815e-01
#
# ...

# %%
n_4_no_wrap_edge_list = [
    ("Q0", "Q1", "qutrit-qutrit", "blue"),
    ("Q0", "Q3", "qutrit-qutrit", "blue"),
    ("Q1", "Q3", "qutrit-qutrit", "blue"),
    ("Q1", "Q2", "qutrit-qutrit", "blue"),
    ("Q2", "Q3", "qutrit-qutrit", "blue"),
    ("Q0", "SNAIL", "snail-qutrit", "orange"),
    ("Q1", "SNAIL", "snail-qutrit", "orange"),
    ("Q2", "SNAIL", "snail-qutrit", "orange"),
    ("Q3", "SNAIL", "snail-qutrit", "orange"),
]
qmg_4_no_wrap = QutritModuleGraph(num_qutrits=4, edge_type="custom", edges=n_4_no_wrap_edge_list)

optimizer = GateFidelityOptimizer(
    qmg_4_no_wrap,
    min_bare_space_ghz=0.12,
    lambdaq=0.08,
    eta=1.8,
    g3=60e6,
    qubit_bounds=(3.3, 5.7),
    snail_bounds=(4.2, 4.7),
    use_lifetime=True,
)

optimizer.optimize_frequencies(5000)
optimizer.report_results()
# Out:
# 100%|██████████| 5000/5000 [09:43<00:00,  8.57it/s]
# Optimization terminated successfully.
# Qubit Frequencies: [3.54066554 5.7        5.33993239 3.30066554] GHz
# SNAIL Frequency: 4.462094112837223 GHz
# Gate Infidelities:
#   Gate ('Q0', 'Q1'): 2.159334 GHz → fidelity (no lifetime loss): 9.966999e-01, fidelity (with lifetime loss): 9.919386e-01
#   Gate ('Q0', 'Q3'): 0.240000 GHz → fidelity (no lifetime loss): 9.963466e-01, fidelity (with lifetime loss): 9.950589e-01
#   Gate ('Q1', 'Q3'): 2.399334 GHz → fidelity (no lifetime loss): 9.954628e-01, fidelity (with lifetime loss): 9.912754e-01
#   Gate ('Q1', 'Q2'): 0.360068 GHz → fidelity (no lifetime loss): 9.945692e-01, fidelity (with lifetime loss): 9.932223e-01
#   Gate ('Q3', 'Q2'): 2.039267 GHz → fidelity (no lifetime loss): 9.954194e-01, fidelity (with lifetime loss): 9.913505e-01
#
# Average Gate fidelity (no lifetime loss): 0.9957659289219916
# Average Gate fidelity (with lifetime loss): 0.9927253635567457

# %%
n_4_no_wrap_edge_list = [
    ("Q0", "Q1", "qutrit-qutrit", "blue"),
    ("Q0", "Q3", "qutrit-qutrit", "blue"),
    ("Q1", "Q3", "qutrit-qutrit", "blue"),
    ("Q1", "Q2", "qutrit-qutrit", "blue"),
    ("Q2", "Q3", "qutrit-qutrit", "blue"),
    ("Q0", "SNAIL", "snail-qutrit", "orange"),
    ("Q1", "SNAIL", "snail-qutrit", "orange"),
    ("Q2", "SNAIL", "snail-qutrit", "orange"),
    ("Q3", "SNAIL", "snail-qutrit", "orange"),
]
qmg_4_no_wrap = QutritModuleGraph(num_qutrits=4, edge_type="custom", edges=n_4_no_wrap_edge_list)

optimizer = GateFidelityOptimizer(
    qmg_4_no_wrap,
    min_bare_space_ghz=0.12,
    lambdaq=0.08,
    eta=1.8,
    g3=60e6,
    qubit_bounds=(3.3, 5.7),
    snail_bounds=(4.2, 4.7),
    use_lifetime=True,
)

optimizer.optimize_frequencies(5000)
optimizer.report_results()

# %% [markdown]
# # 2 SNAIL System
# ## 5 Transmon divided in 2
# Use 2 SNAILs, the first between 0, 1, and 3, the second between 1, 2, and 4.

# %%
n_3_edge_list = [
    ("Q0", "Q1", "qutrit-qutrit", "blue"),
    ("Q0", "Q3", "qutrit-qutrit", "blue"),
    ("Q1", "Q3", "qutrit-qutrit", "blue"),
    ("Q1", "Q2", "qutrit-qutrit", "blue"),
    ("Q1", "Q4", "qutrit-qutrit", "blue"),
    ("Q2", "Q4", "qutrit-qutrit", "blue"),
    ("Q0", "SNAIL", "snail-qutrit", "orange"),
    ("Q1", "SNAIL", "snail-qutrit", "orange"),
    ("Q2", "SNAIL", "snail-qutrit", "orange"),
]
qmg_3_left = QutritModuleGraph(num_qutrits=5, edge_type="custom", edges=n_3_edge_list)

optimizer = GateFidelityOptimizer(
    qmg_3_left,
    min_bare_space_ghz=0.12,
    lambdaq=0.08,
    eta=1.8,
    g3=60e6,
    qubit_bounds=(3.3, 5.7),
    snail_bounds=(4.2, 4.7),
    use_lifetime=True,
)

optimizer.optimize_frequencies(5000)
optimizer.report_results()
# Out:
# 100%|██████████| 5000/5000 [15:30<00:00,  5.38it/s]
# Optimization terminated successfully.
# Qubit Frequencies: [5.45459846 3.76760512 5.21430954 4.12792667 4.97398799] GHz
# SNAIL Frequency: 4.582116558913652 GHz
# Gate Infidelities:
#   Gate ('Q0', 'Q1'): 1.686993 GHz → fidelity (no lifetime loss): 9.935135e-01, fidelity (with lifetime loss): 9.907980e-01
#   Gate ('Q0', 'Q3'): 1.326672 GHz → fidelity (no lifetime loss): 9.905374e-01, fidelity (with lifetime loss): 9.884380e-01
#   Gate ('Q1', 'Q3'): 0.360322 GHz → fidelity (no lifetime loss): 9.828260e-01, fidelity (with lifetime loss): 9.815260e-01
#   Gate ('Q1', 'Q2'): 1.446704 GHz → fidelity (no lifetime loss): 9.940524e-01, fidelity (with lifetime loss): 9.917752e-01
#   Gate ('Q1', 'Q4'): 1.206383 GHz → fidelity (no lifetime loss): 9.851631e-01, fidelity (with lifetime loss): 9.832208e-01
#   Gate ('Q2', 'Q4'): 0.240322 GHz → fidelity (no lifetime loss): 9.905790e-01, fidelity (with lifetime loss): 9.893271e-01
#
# ...

# %%
n_4_double_snail_edge_list = [
    ("Q0", "Q1", "qutrit-qutrit", "blue"),
    ("Q0", "Q3", "qutrit-qutrit", "blue"),
    ("Q1", "Q3", "qutrit-qutrit", "blue"),
    ("Q1", "Q2", "qutrit-qutrit", "blue"),
    ("Q2", "Q3", "qutrit-qutrit", "blue"),
    ("Q0", "SNAIL", "snail-qutrit", "orange"),
    ("Q1", "SNAIL", "snail-qutrit", "orange"),
    ("Q3", "SNAIL", "snail-qutrit", "orange"),
]
qmg_3_left = QutritModuleGraph(num_qutrits=4, edge_type="custom", edges=n_4_double_snail_edge_list)

optimizer = GateFidelityOptimizer(
    qmg_3_left,
    min_bare_space_ghz=0.12,
    lambdaq=0.08,
    eta=1.8,
    g3=60e6,
    qubit_bounds=(3.3, 5.7),
    snail_bounds=(4.2, 4.7),
    use_lifetime=True,
)

optimizer.optimize_frequencies(5000)
optimizer.report_results()
# Out:
# 100%|██████████| 5000/5000 [09:31<00:00,  8.74it/s]
# Optimization terminated successfully.
# Qubit Frequencies: [5.7        5.57035731 4.94732644 5.19884187] GHz
# SNAIL Frequency: 4.268133451770742 GHz
# Gate Infidelities:
#   Gate ('Q0', 'Q1'): 0.129643 GHz → fidelity (no lifetime loss): 9.999399e-01, fidelity (with lifetime loss): 9.986540e-01
#   Gate ('Q0', 'Q3'): 0.501158 GHz → fidelity (no lifetime loss): 9.956942e-01, fidelity (with lifetime loss): 9.942045e-01
#   Gate ('Q1', 'Q3'): 0.371515 GHz → fidelity (no lifetime loss): 9.974011e-01, fidelity (with lifetime loss): 9.959894e-01
#   Gate ('Q1', 'Q2'): 0.623031 GHz → fidelity (no lifetime loss): 9.901021e-01, fidelity (with lifetime loss): 9.885369e-01
#   Gate ('Q3', 'Q2'): 0.251515 GHz → fidelity (no lifetime loss): 9.982019e-01, fidelity (with lifetime loss): 9.968563e-01
#
# Average Gate fidelity (no lifetime loss): 0.9983569467409434
# Average Gate fidelity (with lifetime loss): 0.9959222867332886
