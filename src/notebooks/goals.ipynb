# %% [markdown]
# We want to optimize the fidelity of our module, including error detection and recovery.
#
# Since we are able to obtain $\sqrt{\text{iSWAP}}$ between the |0> and |1> states and the |1> and |2> states, we can use that to benchmark fidelity of the module. Since we require more |0> <-> |1> CNOTS, we can weight the total fidelity by some proportion of the sum, giving a higher weight to the |0> <-> |1> state gates.

# %% [markdown]
# Determine if we want to consider maxmizing total gate fidelity, or correctable gate fidelity. Correctable gate fidelity discards erasure errors since we can correct them. Consider having a penalty on erasure errors insteaed, proportional to the fidelity hit in order to recover from it.
